# %% [markdown]
# link:https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary/a5a

# %%
import numpy as np
import pandas as pd
import urllib

import sklearn
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import train_test_split

from sklearn import metrics
from sklearn.metrics import accuracy_score

import re

# %%
#url ='https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary/a5a'
#raw_data = urllib.urlopen(url)


#s = ur.urlopen(url)
#sl = s.read()
#print(sl)


#sp = raw_data.split(' ')
#datasets = np.loadtxt(sp, delimiter=':')
#dd = data.isnull().sum()
#print(data.describe)
#print(data.head)
#X = df.loc[2]
#print(data)
#print (type(X))
# creating a dataframe from list
#df = pd.DataFrame(data)
#X = df.iloc[0:100]

test_list = ["", "GeeksforGeeks", ":1", "is", "best", ""]




##print(len(xx[5][3])) #look here it give the length of the string, we have to find a way that when we subtract 2 from this string it should return the data of index[2] whicth is for ex 14
#df = pd.DataFrame(data)
#while('3:1' in str(xx)) : 
#    xx.remove("3:1")
#    print ("Modified list is : " + str(xx))
#print(test_list[0:10])


#f = re.sub(':1', '',str(df[0:1]))
#ff = re.sub('NaN', '', str(f))

#print(df)
#print(type(ff))
#x = np.array(ff)
#print(type(x))
#X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
#Y = np.array([1, 1, 1, 2, 2, 2])
#clf = GaussianNB()
#clf.fit(X, Y)
#print(clf.predict([[-0.8, -1]]))

#clf_pf = GaussianNB()
#clf_pf.partial_fit(X, Y, np.unique(Y))
#print(clf_pf.predict([[-0.8, -1]]))
#print(re.findall('1', str(f[1])))




# read csv file
data = pd.read_csv("datasets.csv")
datasets = data.to_numpy() #change dataframe to numpy array this is array numpy is a library

######## length and type of datasets ############
sets_type = type(datasets)
le = len(datasets)
print('Datasets type',sets_type)
print('length', le)
################################################

dd = datasets.reshape(-1, 1)

for arr in datasets[0:50]:
    #print(arr)
    a = arr[0]
    if a == -1:
        aa = arr[1:14]
        aaa = aa.reshape(-1, 1)
        aux = re.sub(':1', '',str(aaa))
        x = re.sub('nan', '0', aux)
        ss = numpy.fromstring(x, dtype=int, sep=",")
        #print('-1')
        print(ss)
    
    
#     if a == 1:
#         bb = arr[1:14]
#         bbb = bb.reshape(-1, 1)
#         aux = re.sub(':1', '',str(bb))
#         y = re.sub('nan', '0', aux)
#         #print('1')
#         #print(y)
        
        
        
#     neigh = KNeighborsClassifier(n_neighbors=3)
#     neigh.fit(x, y)
#     print(neigh.predict([[1.1]]))
#     print(neigh.predict_proba([[0.9]]))





##################### KNN #########################
X = [['0'], ['1'], ['2'], ['3']] #training data
y = [0, 0, 1, 1]         # target data >50k  year

neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X, y)
print(neigh.predict([[1.1]]))
print(neigh.predict_proba([[0.9]]))
##################################################


# f = re.sub(':1', '',str(xx[0:1]))
# ff = re.sub('NaN', '', f)
# print(ff)
# print(type(ff))
# zz = np.frombuffer(ff, dtype=str)
# Out:
# ('Datasets type', <type 'numpy.ndarray'>)
# ('length', 6414)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-383-639f53782e58> in <module>()
#      90
#      91     neigh = KNeighborsClassifier(n_neighbors=3)
# ---> 92     neigh.fit(x, y)
#      93     print(neigh.predict([[1.1]]))
#      94     print(neigh.predict_proba([[0.9]]))
#
# /home/mohammed/anaconda3/envs/python2/lib/python2.7/site-packages/sklearn/neighbors/base.pyc in fit(self, X, y)
#     889         """
#     890         if not isinstance(X, (KDTree, BallTree)):
# --> 891             X, y = check_X_y(X, y, "csr", multi_output=True)
#     892
#     893         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# /home/mohammed/anaconda3/envs/python2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /home/mohammed/anaconda3/envs/python2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     543                     "Reshape your data either using array.reshape(-1, 1) if "
#     544                     "your data has a single feature or array.reshape(1, -1) "
# --> 545                     "if it contains a single sample.".format(array))
#     546             # If input is 1D raise error
#     547             if array.ndim == 1:
#
# ValueError: Expected 2D array, got scalar array instead:
# array=[['3']
#  ['11']
#  ['14']
#  ['19']
#  ['39']
#  ['42']
#  ['55']
#  ['64']
#  ['67']
#  ['73']
#  ['75']
#  ['76']
#  ['80']].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
